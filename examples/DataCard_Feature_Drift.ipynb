# %%
import os

os.environ["GOOGLE_ACCOUNT_JSON_BASE64"] = "service account credentials (see pinned chat in slack or use gcloud sdk)"
os.environ["POETRY_HTTP_BASIC_SHIPT_RESOLVE_USERNAME"]="secret username"
os.environ["POETRY_HTTP_BASIC_SHIPT_RESOLVE_PASSWORD"]="secret pass"

# %%
# !pip install -r requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://steven.forrester:****@artifactory.shipt.com/artifactory/api/pypi/pypi-virtual/simple
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.0/17.0 MB 25.1 MB/s eta 0:00:00m eta 0:00:010:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.8/45.8 kB 1.1 MB/s eta 0:00:00
# ...
#   Using cached https://artifactory.shipt.com/artifactory/api/pypi/pypi-virtual/pyshipt/2.1.8/pyshipt-2.1.8-py3-none-any.whl (56 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 17.0 MB/s eta 0:00:00m eta 0:00:010:01
# ...
#   Using cached https://artifactory.shipt.com/artifactory/api/pypi/pypi-virtual/pyshipt-experiments/2.9.0/pyshipt_experiments-2.9.0-py3-none-any.whl (13 kB)
# ...
#   Using cached https://artifactory.shipt.com/artifactory/api/pypi/pypi-virtual/packages/packages/29/cd/89aafa39d7b9d30c82f4f82f50e13ba826bb273ade972befb273c5f6c05e/slackclient-2.9.4-py2.py3-none-any.whl (97 kB)
# ...

# %%
from opsml_data import DataCard, DataRegistry, DriftDetector, DriftVisualizer
import numpy as np
import pandas as pd

# %%
# instantiate registry
registry = DataRegistry()

# %%
# Create fake data
mu_1 = -4  # mean of the first distribution
mu_2 = 4  # mean of the second distribution
X_train = np.random.normal(mu_1, 2.0, size=(1000, 10))
cat = np.random.randint(0, 3, 1000).reshape(-1, 1)
X_train = np.hstack((X_train, cat))

X_test = np.random.normal(mu_2, 2.0, size=(1000, 10))
cat = np.random.randint(2, 5, 1000).reshape(-1, 1)
X_test = np.hstack((X_test, cat))

y_train = np.random.randint(1, 100, size=(1000, 1))
y_test = np.random.randint(2, 100, size=(1000, 1))

col_names = []
for i in range(0, X_train.shape[1]):
    col_names.append(f"col_{i}")

X_train = pd.DataFrame(X_train, columns=col_names)
X_test = pd.DataFrame(X_test, columns=col_names)
X_train.head()
# Out:
#       col_0     col_1     col_2     col_3     col_4     col_5     col_6  \
# 0 -4.699456 -2.129630 -1.031012 -6.448732 -2.613063 -4.627918 -7.099859
# 1 -3.528827 -0.736135 -5.322930 -0.008724 -6.428887 -6.011611 -2.917212
# 2 -6.113920 -5.181020 -5.750437 -5.578761 -3.093922 -3.144952 -6.114517
# 3 -4.505134 -6.073289 -5.471159 -2.818853 -2.216167 -3.277433 -2.351686
# 4 -3.432316 -5.305749 -1.210931 -2.131027 -8.499907 -5.350071  1.499716
#
#       col_7     col_8     col_9  col_10
# 0 -4.558165 -2.599741 -3.958922     1.0
# 1 -7.235475 -0.775409 -3.748981     2.0
# 2 -3.907269 -5.780322 -2.239696     2.0
# 3 -1.985481 -5.930658 -4.591427     2.0
# 4 -3.422657 -0.923902 -4.243465     2.0

# %% [markdown]
# ## Drift Detector
#
# - To visualize drift between two dataframes with the same feature set and types, we utilize the **DriftDetector**
# - With the **DriftDetector** you specify
#     - x_reference: reference dataframe
#     - x_current: current_dataframe
#     - y_reference: reference target (numpy array)
#     - y_current: current target (numpy array)
#     - dependent_var_name: Name of dependent variable
#     - categorical_features: List of categorical features (if any)
#
#   **Note**: DriftDetector assumes categorical features have been encoded (e.g. label encoding)

# %%
#run drift report
drift_detector = DriftDetector(
    x_reference=X_train,
    x_current=X_test,
    y_reference=y_train,
    y_current=y_test,
    target_feature_name="target",
    categorical_features=["col_10"],
)

# run the detector
drift_report = drift_detector.run_drift_diagnostics()

#visualize the report
drift_detector.visualize_report()
# Out:
# /Users/steven.forrester/Library/Caches/pypoetry/virtualenvs/jupyter-local-dev-n7or5Q-O-py3.9/lib/python3.9/site-packages/altair/utils/core.py:317: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for col_name, dtype in df.dtypes.iteritems():
# alt.VConcatChart(...)

# %% [markdown]
# ### What's in the visualization?
#
# The drift visualization comprises 3 main features
#
# 1. Numeric feature distribution plots. Under the hood, **DriftDetector** takes all numeric features and computes distributions and intersections between reference and current data and overlays the distributions for visualization. This way, you can quickly compare if your features have significant drift in their distributions.
#
# 2. Categorical feature distribution plots. Similar to numeric feature plots, **DriftDetector** computes the percentage of records that fall into a given bin of a categorical feature.
#
# 3. Feature AUC. DriftDetector runs a simple Logistic Regression to determine if it can reliably tell whether a given data record has come from the reference or current dataframe given the available features. If significant drift has been detected (any feature with an AUC >.6) the feature is highlighted in red and indicates significant drift has been detected between current and reference features

# %%
# add data to dataframe for saving into DataCard
X_train["target"] = y_train
X_test["target"] = y_test
X_train["split"] = "train"
X_test["split"] = "test"
model_data = pd.concat([X_train, X_test])

# Data card
DATA_NAME = "synthetic_data"
TEAM = "SPMS"
USER_EMAIL = "steven.forrester@shipt.com"

# notice that column split is specified differently this time
DATA_SPLITS = [
    {"label": "train", "column": "split", "column_value": "train"},
    {"label": "train", "column": "split", "column_value": "test"},
]

data_card = DataCard(
    data_name=DATA_NAME,
    team=TEAM,
    user_email=USER_EMAIL,
    data=model_data,
    data_splits=DATA_SPLITS,
    dependent_vars=["target"],
    drift_report=drift_report,
)

#register
registry.register_data(data_card=data_card)
# Out:
# {"level": "INFO", "message": "Table: synthetic_data registered as version 2", "timestamp": "2023-01-09T02:15:23.030319Z", "app_env": "staging", "host": null, "version": null}

# %%
# load (for testing purposes)
loaded_data_card = registry.load_data(data_name=DATA_NAME, team=TEAM, version=data_card.version)

# %% [markdown]
# ### DriftVisualizer
#
# You can also feed drift reports into the DriftVisualizer (Useful if you are loading a DataCard that already has a drift report)

# %%
DriftVisualizer(drift_report=drift_report).visualize_report()
# Out:
# alt.VConcatChart(...)
