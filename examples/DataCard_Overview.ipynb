# %% [markdown]
# # Overview
#
# The following example shows how to create a DataCard, register it, and then load it/other DataCards for collaboration and reproducibility

# %%
import os

os.environ["GOOGLE_ACCOUNT_JSON_BASE64"] = "service account credentials (see pinned chat in slack or use gcloud sdk)"
os.environ["POETRY_HTTP_BASIC_SHIPT_RESOLVE_USERNAME"]="secret username"
os.environ["POETRY_HTTP_BASIC_SHIPT_RESOLVE_PASSWORD"]="secret pass"

# %%
# !pip install -r requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://steven.forrester:****@artifactory.shipt.com/artifactory/api/pypi/pypi-virtual/simple
# Requirement already satisfied: numpy==1.21.6 in /Users/steven.forrester/Library/Caches/pypoetry/virtualenvs/jupyter-local-dev-n7or5Q-O-py3.9/lib/python3.9/site-packages (from -r requirements.txt (line 1)) (1.21.6)
# Collecting opsml-data==0.1.1rc1673236397
#   Downloading https://artifactory.shipt.com/artifactory/api/pypi/pypi-virtual/opsml-data/0.1.1rc1673236397/opsml_data-0.1.1rc1673236397-py3-none-any.whl (45 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.9/45.9 kB 1.1 MB/s eta 0:00:00
# Requirement already satisfied: pydantic<2.0.0,>=1.10.2 in /Users/steven.forrester/Library/Caches/pypoetry/virtualenvs/jupyter-local-dev-n7or5Q-O-py3.9/lib/python3.9/site-packages (from opsml-data==0.1.1rc1673236397->-r requirements.txt (line 3)) (1.10.2)
# Requirement already satisfied: altair<5.0.0,>=4.2.0 in /Users/steven.forrester/Library/Caches/pypoetry/virtualenvs/jupyter-local-dev-n7or5Q-O-py3.9/lib/python3.9/site-packages (from opsml-data==0.1.1rc1673236397->-r requirements.txt (line 3)) (4.2.0)
# Requirement already satisfied: google-auth==1.35.0 in /Users/steven.forrester/Library/Caches/pypoetry/virtualenvs/jupyter-local-dev-n7or5Q-O-py3.9/lib/python3.9/site-packages (from opsml-data==0.1.1rc1673236397->-r requirements.txt (line 3)) (1.35.0)
# Requirement already satisfied: gcsfs<2023.0.0,>=2022.11.0 in /Users/steven.forrester/Library/Caches/pypoetry/virtualenvs/jupyter-local-dev-n7or5Q-O-py3.9/lib/python3.9/site-packages (from opsml-data==0.1.1rc1673236397->-r requirements.txt (line 3)) (2022.11.0)
# Requirement already satisfied: google-cloud-secret-manager<3.0.0,>=2.12.2 in /Users/steven.forrester/Library/Caches/pypoetry/virtualenvs/jupyter-local-dev-n7or5Q-O-py3.9/lib/python3.9/site-packages (from opsml-data==0.1.1rc1673236397->-r requirements.txt (line 3)) (2.12.6)
# Requirement already satisfied: sqlalchemy[mypy]<2.0.0,>=1.4.46 in /Users/steven.forrester/Library/Caches/pypoetry/virtualenvs/jupyter-local-dev-n7or5Q-O-py3.9/lib/python3.9/site-packages (from opsml-data==0.1.1rc1673236397->-r requirements.txt (line 3)) (1.4.46)
# Requirement already satisfied: google-cloud-storage==1.44.0 in /Users/steven.forrester/Library/Caches/pypoetry/virtualenvs/jupyter-local-dev-n7or5Q-O-py3.9/lib/python3.9/site-packages (from opsml-data==0.1.1rc1673236397->-r requirements.txt (line 3)) (1.44.0)
# Requirement already satisfied: pyarrow==8.0.0 in /Users/steven.forrester/Library/Caches/pypoetry/virtualenvs/jupyter-local-dev-n7or5Q-O-py3.9/lib/python3.9/site-packages (from opsml-data==0.1.1rc1673236397->-r requirements.txt (line 3)) (8.0.0)
# Requirement already satisfied: pyshipt==2.1.8 in /Users/steven.forrester/Library/Caches/pypoetry/virtualenvs/jupyter-local-dev-n7or5Q-O-py3.9/lib/python3.9/site-packages (from opsml-data==0.1.1rc1673236397->-r requirements.txt (line 3)) (2.1.8)
# Requirement already satisfied: pyshipt-logging<0.5.0,>=0.4.3 in /Users/steven.forrester/Library/Caches/pypoetry/virtualenvs/jupyter-local-dev-n7or5Q-O-py3.9/lib/python3.9/site-packages (from opsml-data==0.1.1rc1673236397->-r requirements.txt (line 3)) (0.4.6)
# Requirement already satisfied: scikit-learn>=1.0 in /Users/steven.forrester/Library/Caches/pypoetry/virtualenvs/jupyter-local-dev-n7or5Q-O-py3.9/lib/python3.9/site-packages (from opsml-data==0.1.1rc1673236397->-r requirements.txt (line 3)) (1.1.1)
# Requirement already satisfied: cloud-sql-python-connector[pymysql]<0.9.0,>=0.8.1 in /Users/steven.forrester/Library/Caches/pypoetry/virtualenvs/jupyter-local-dev-n7or5Q-O-py3.9/lib/python3.9/site-packages (from opsml-data==0.1.1rc1673236397->-r requirements.txt (line 3)) (0.8.1)
# Requirement already satisfied: pandas<2.0.0,>=1.5.0 in /Users/steven.forrester/Library/Caches/pypoetry/virtualenvs/jupyter-local-dev-n7or5Q-O-py3.9/lib/python3.9/site-packages (from opsml-data==0.1.1rc1673236397->-r requirements.txt (line 3)) (1.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/steven.forrester/Library/Caches/pypoetry/virtualenvs/jupyter-local-dev-n7or5Q-O-py3.9/lib/python3.9/site-packages (from google-auth==1.35.0->opsml-data==0.1.1rc1673236397->-r requirements.txt (line 3)) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/steven.forrester/Library/Caches/pypoetry/virtualenvs/jupyter-local-dev-n7or5Q-O-py3.9/lib/python3.9/site-packages (from google-auth==1.35.0->opsml-data==0.1.1rc1673236397->-r requirements.txt (line 3)) (4.9)
# Requirement already satisfied: setuptools>=40.3.0 in /Users/steven.forrester/Library/Caches/pypoetry/virtualenvs/jupyter-local-dev-n7or5Q-O-py3.9/lib/python3.9/site-packages (from google-auth==1.35.0->opsml-data==0.1.1rc1673236397->-r requirements.txt (line 3)) (65.6.3)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /Users/steven.forrester/Library/Caches/pypoetry/virtualenvs/jupyter-local-dev-n7or5Q-O-py3.9/lib/python3.9/site-packages (from google-auth==1.35.0->opsml-data==0.1.1rc1673236397->-r requirements.txt (line 3)) (4.2.4)
# Requirement already satisfied: six>=1.9.0 in /Users/steven.forrester/Library/Caches/pypoetry/virtualenvs/jupyter-local-dev-n7or5Q-O-py3.9/lib/python3.9/site-packages (from google-auth==1.35.0->opsml-data==0.1.1rc1673236397->-r requirements.txt (line 3)) (1.16.0)
# Requirement already satisfied: google-cloud-core<3.0dev,>=1.6.0 in /Users/steven.forrester/Library/Caches/pypoetry/virtualenvs/jupyter-local-dev-n7or5Q-O-py3.9/lib/python3.9/site-packages (from google-cloud-storage==1.44.0->opsml-data==0.1.1rc1673236397->-r requirements.txt (line 3)) (2.3.2)
# Requirement already satisfied: protobuf in /Users/steven.forrester/Library/Caches/pypoetry/virtualenvs/jupyter-local-dev-n7or5Q-O-py3.9/lib/python3.9/site-packages (from google-cloud-storage==1.44.0->opsml-data==0.1.1rc1673236397->-r requirements.txt (line 3)) (3.20.3)
# Requirement already satisfied: google-api-core<3.0dev,>=1.29.0 in /Users/steven.forrester/Library/Caches/pypoetry/virtualenvs/jupyter-local-dev-n7or5Q-O-py3.9/lib/python3.9/site-packages (from google-cloud-storage==1.44.0->opsml-data==0.1.1rc1673236397->-r requirements.txt (line 3)) (2.10.2)
# Requirement already satisfied: requests<3.0.0dev,>=2.18.0 in /Users/steven.forrester/Library/Caches/pypoetry/virtualenvs/jupyter-local-dev-n7or5Q-O-py3.9/lib/python3.9/site-packages (from google-cloud-storage==1.44.0->opsml-data==0.1.1rc1673236397->-r requirements.txt (line 3)) (2.28.1)
# Requirement already satisfied: google-resumable-media<3.0dev,>=1.3.0 in /Users/steven.forrester/Library/Caches/pypoetry/virtualenvs/jupyter-local-dev-n7or5Q-O-py3.9/lib/python3.9/site-packages (from google-cloud-storage==1.44.0->opsml-data==0.1.1rc1673236397->-r requirements.txt (line 3)) (2.4.0)
# Requirement already satisfied: pyshipt-experiments<3.0.0,>=2.1.0 in /Users/steven.forrester/Library/Caches/pypoetry/virtualenvs/jupyter-local-dev-n7or5Q-O-py3.9/lib/python3.9/site-packages (from pyshipt==2.1.8->opsml-data==0.1.1rc1673236397->-r requirements.txt (line 3)) (2.9.0)
# Requirement already satisfied: snowflake-connector-python<3.0.0,>=2.7.6 in /Users/steven.forrester/Library/Caches/pypoetry/virtualenvs/jupyter-local-dev-n7or5Q-O-py3.9/lib/python3.9/site-packages (from pyshipt==2.1.8->opsml-data==0.1.1rc1673236397->-r requirements.txt (line 3)) (2.9.0)
# Requirement already satisfied: python-json-logger<3.0.0,>=2.0.1 in /Users/steven.forrester/Library/Caches/pypoetry/virtualenvs/jupyter-local-dev-n7or5Q-O-py3.9/lib/python3.9/site-packages (from pyshipt==2.1.8->opsml-data==0.1.1rc1673236397->-r requirements.txt (line 3)) (2.0.4)
# Requirement already satisfied: pyshipt-streams<4.0.0,>=3.0.0 in /Users/steven.forrester/Library/Caches/pypoetry/virtualenvs/jupyter-local-dev-n7or5Q-O-py3.9/lib/python3.9/site-packages (from pyshipt==2.1.8->opsml-data==0.1.1rc1673236397->-r requirements.txt (line 3)) (3.2.0)
# Requirement already satisfied: slackclient<3.0.0,>=2.8.1 in /Users/steven.forrester/Library/Caches/pypoetry/virtualenvs/jupyter-local-dev-n7or5Q-O-py3.9/lib/python3.9/site-packages (from pyshipt==2.1.8->opsml-data==0.1.1rc1673236397->-r requirements.txt (line 3)) (2.9.4)
# Requirement already satisfied: jinja2<4.0.0,>=3.0.3 in /Users/steven.forrester/Library/Caches/pypoetry/virtualenvs/jupyter-local-dev-n7or5Q-O-py3.9/lib/python3.9/site-packages (from pyshipt==2.1.8->opsml-data==0.1.1rc1673236397->-r requirements.txt (line 3)) (3.1.2)
# Requirement already satisfied: fastparquet<0.9.0,>=0.8.0 in /Users/steven.forrester/Library/Caches/pypoetry/virtualenvs/jupyter-local-dev-n7or5Q-O-py3.9/lib/python3.9/site-packages (from pyshipt==2.1.8->opsml-data==0.1.1rc1673236397->-r requirements.txt (line 3)) (0.8.3)
# Requirement already satisfied: inflection<0.6.0,>=0.5.0 in /Users/steven.forrester/Library/Caches/pypoetry/virtualenvs/jupyter-local-dev-n7or5Q-O-py3.9/lib/python3.9/site-packages (from pyshipt==2.1.8->opsml-data==0.1.1rc1673236397->-r requirements.txt (line 3)) (0.5.1)
# Requirement already satisfied: boto3==1.21.20 in /Users/steven.forrester/Library/Caches/pypoetry/virtualenvs/jupyter-local-dev-n7or5Q-O-py3.9/lib/python3.9/site-packages (from pyshipt==2.1.8->opsml-data==0.1.1rc1673236397->-r requirements.txt (line 3)) (1.21.20)
# Requirement already satisfied: more-itertools<9.0.0,>=8.6.0 in /Users/steven.forrester/Library/Caches/pypoetry/virtualenvs/jupyter-local-dev-n7or5Q-O-py3.9/lib/python3.9/site-packages (from pyshipt==2.1.8->opsml-data==0.1.1rc1673236397->-r requirements.txt (line 3)) (8.14.0)
# Requirement already satisfied: psycopg2<3.0.0,>=2.9.3 in /Users/steven.forrester/Library/Caches/pypoetry/virtualenvs/jupyter-local-dev-n7or5Q-O-py3.9/lib/python3.9/site-packages (from pyshipt==2.1.8->opsml-data==0.1.1rc1673236397->-r requirements.txt (line 3)) (2.9.5)
# Requirement already satisfied: botocore<1.25.0,>=1.24.20 in /Users/steven.forrester/Library/Caches/pypoetry/virtualenvs/jupyter-local-dev-n7or5Q-O-py3.9/lib/python3.9/site-packages (from boto3==1.21.20->pyshipt==2.1.8->opsml-data==0.1.1rc1673236397->-r requirements.txt (line 3)) (1.24.46)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /Users/steven.forrester/Library/Caches/pypoetry/virtualenvs/jupyter-local-dev-n7or5Q-O-py3.9/lib/python3.9/site-packages (from boto3==1.21.20->pyshipt==2.1.8->opsml-data==0.1.1rc1673236397->-r requirements.txt (line 3)) (0.10.0)
# Requirement already satisfied: s3transfer<0.6.0,>=0.5.0 in /Users/steven.forrester/Library/Caches/pypoetry/virtualenvs/jupyter-local-dev-n7or5Q-O-py3.9/lib/python3.9/site-packages (from boto3==1.21.20->pyshipt==2.1.8->opsml-data==0.1.1rc1673236397->-r requirements.txt (line 3)) (0.5.2)
# Requirement already satisfied: toolz in /Users/steven.forrester/Library/Caches/pypoetry/virtualenvs/jupyter-local-dev-n7or5Q-O-py3.9/lib/python3.9/site-packages (from altair<5.0.0,>=4.2.0->opsml-data==0.1.1rc1673236397->-r requirements.txt (line 3)) (0.12.0)
# Requirement already satisfied: jsonschema>=3.0 in /Users/steven.forrester/Library/Caches/pypoetry/virtualenvs/jupyter-local-dev-n7or5Q-O-py3.9/lib/python3.9/site-packages (from altair<5.0.0,>=4.2.0->opsml-data==0.1.1rc1673236397->-r requirements.txt (line 3)) (3.2.0)
# Requirement already satisfied: entrypoints in /Users/steven.forrester/Library/Caches/pypoetry/virtualenvs/jupyter-local-dev-n7or5Q-O-py3.9/lib/python3.9/site-packages (from altair<5.0.0,>=4.2.0->opsml-data==0.1.1rc1673236397->-r requirements.txt (line 3)) (0.4)
# Requirement already satisfied: aiohttp in /Users/steven.forrester/Library/Caches/pypoetry/virtualenvs/jupyter-local-dev-n7or5Q-O-py3.9/lib/python3.9/site-packages (from cloud-sql-python-connector[pymysql]<0.9.0,>=0.8.1->opsml-data==0.1.1rc1673236397->-r requirements.txt (line 3)) (3.8.3)
# Requirement already satisfied: cryptography in /Users/steven.forrester/Library/Caches/pypoetry/virtualenvs/jupyter-local-dev-n7or5Q-O-py3.9/lib/python3.9/site-packages (from cloud-sql-python-connector[pymysql]<0.9.0,>=0.8.1->opsml-data==0.1.1rc1673236397->-r requirements.txt (line 3)) (38.0.4)
# Requirement already satisfied: PyMySQL==1.0.2 in /Users/steven.forrester/Library/Caches/pypoetry/virtualenvs/jupyter-local-dev-n7or5Q-O-py3.9/lib/python3.9/site-packages (from cloud-sql-python-connector[pymysql]<0.9.0,>=0.8.1->opsml-data==0.1.1rc1673236397->-r requirements.txt (line 3)) (1.0.2)
# Requirement already satisfied: decorator>4.1.2 in /Users/steven.forrester/Library/Caches/pypoetry/virtualenvs/jupyter-local-dev-n7or5Q-O-py3.9/lib/python3.9/site-packages (from gcsfs<2023.0.0,>=2022.11.0->opsml-data==0.1.1rc1673236397->-r requirements.txt (line 3)) (5.1.1)
# Requirement already satisfied: google-auth-oauthlib in /Users/steven.forrester/Library/Caches/pypoetry/virtualenvs/jupyter-local-dev-n7or5Q-O-py3.9/lib/python3.9/site-packages (from gcsfs<2023.0.0,>=2022.11.0->opsml-data==0.1.1rc1673236397->-r requirements.txt (line 3)) (0.5.3)
# Requirement already satisfied: fsspec==2022.11.0 in /Users/steven.forrester/Library/Caches/pypoetry/virtualenvs/jupyter-local-dev-n7or5Q-O-py3.9/lib/python3.9/site-packages (from gcsfs<2023.0.0,>=2022.11.0->opsml-data==0.1.1rc1673236397->-r requirements.txt (line 3)) (2022.11.0)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.0 in /Users/steven.forrester/Library/Caches/pypoetry/virtualenvs/jupyter-local-dev-n7or5Q-O-py3.9/lib/python3.9/site-packages (from google-cloud-secret-manager<3.0.0,>=2.12.2->opsml-data==0.1.1rc1673236397->-r requirements.txt (line 3)) (1.22.1)
# Requirement already satisfied: grpc-google-iam-v1<1.0.0dev,>=0.12.4 in /Users/steven.forrester/Library/Caches/pypoetry/virtualenvs/jupyter-local-dev-n7or5Q-O-py3.9/lib/python3.9/site-packages (from google-cloud-secret-manager<3.0.0,>=2.12.2->opsml-data==0.1.1rc1673236397->-r requirements.txt (line 3)) (0.12.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/steven.forrester/Library/Caches/pypoetry/virtualenvs/jupyter-local-dev-n7or5Q-O-py3.9/lib/python3.9/site-packages (from pandas<2.0.0,>=1.5.0->opsml-data==0.1.1rc1673236397->-r requirements.txt (line 3)) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/steven.forrester/Library/Caches/pypoetry/virtualenvs/jupyter-local-dev-n7or5Q-O-py3.9/lib/python3.9/site-packages (from pandas<2.0.0,>=1.5.0->opsml-data==0.1.1rc1673236397->-r requirements.txt (line 3)) (2022.6)
# Requirement already satisfied: typing-extensions>=4.1.0 in /Users/steven.forrester/Library/Caches/pypoetry/virtualenvs/jupyter-local-dev-n7or5Q-O-py3.9/lib/python3.9/site-packages (from pydantic<2.0.0,>=1.10.2->opsml-data==0.1.1rc1673236397->-r requirements.txt (line 3)) (4.4.0)
# Requirement already satisfied: rollbar>=0.15.0 in /Users/steven.forrester/Library/Caches/pypoetry/virtualenvs/jupyter-local-dev-n7or5Q-O-py3.9/lib/python3.9/site-packages (from pyshipt-logging<0.5.0,>=0.4.3->opsml-data==0.1.1rc1673236397->-r requirements.txt (line 3)) (0.16.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/steven.forrester/Library/Caches/pypoetry/virtualenvs/jupyter-local-dev-n7or5Q-O-py3.9/lib/python3.9/site-packages (from scikit-learn>=1.0->opsml-data==0.1.1rc1673236397->-r requirements.txt (line 3)) (3.1.0)
# Requirement already satisfied: scipy>=1.3.2 in /Users/steven.forrester/Library/Caches/pypoetry/virtualenvs/jupyter-local-dev-n7or5Q-O-py3.9/lib/python3.9/site-packages (from scikit-learn>=1.0->opsml-data==0.1.1rc1673236397->-r requirements.txt (line 3)) (1.9.3)
# Requirement already satisfied: joblib>=1.0.0 in /Users/steven.forrester/Library/Caches/pypoetry/virtualenvs/jupyter-local-dev-n7or5Q-O-py3.9/lib/python3.9/site-packages (from scikit-learn>=1.0->opsml-data==0.1.1rc1673236397->-r requirements.txt (line 3)) (1.2.0)
# Requirement already satisfied: greenlet!=0.4.17 in /Users/steven.forrester/Library/Caches/pypoetry/virtualenvs/jupyter-local-dev-n7or5Q-O-py3.9/lib/python3.9/site-packages (from sqlalchemy[mypy]<2.0.0,>=1.4.46->opsml-data==0.1.1rc1673236397->-r requirements.txt (line 3)) (2.0.1)
# Requirement already satisfied: sqlalchemy2-stubs in /Users/steven.forrester/Library/Caches/pypoetry/virtualenvs/jupyter-local-dev-n7or5Q-O-py3.9/lib/python3.9/site-packages (from sqlalchemy[mypy]<2.0.0,>=1.4.46->opsml-data==0.1.1rc1673236397->-r requirements.txt (line 3)) (0.0.2a31)
# Requirement already satisfied: mypy>=0.910 in /Users/steven.forrester/Library/Caches/pypoetry/virtualenvs/jupyter-local-dev-n7or5Q-O-py3.9/lib/python3.9/site-packages (from sqlalchemy[mypy]<2.0.0,>=1.4.46->opsml-data==0.1.1rc1673236397->-r requirements.txt (line 3)) (0.991)
# Requirement already satisfied: attrs>=17.3.0 in /Users/steven.forrester/Library/Caches/pypoetry/virtualenvs/jupyter-local-dev-n7or5Q-O-py3.9/lib/python3.9/site-packages (from aiohttp->cloud-sql-python-connector[pymysql]<0.9.0,>=0.8.1->opsml-data==0.1.1rc1673236397->-r requirements.txt (line 3)) (22.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/steven.forrester/Library/Caches/pypoetry/virtualenvs/jupyter-local-dev-n7or5Q-O-py3.9/lib/python3.9/site-packages (from aiohttp->cloud-sql-python-connector[pymysql]<0.9.0,>=0.8.1->opsml-data==0.1.1rc1673236397->-r requirements.txt (line 3)) (6.0.3)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /Users/steven.forrester/Library/Caches/pypoetry/virtualenvs/jupyter-local-dev-n7or5Q-O-py3.9/lib/python3.9/site-packages (from aiohttp->cloud-sql-python-connector[pymysql]<0.9.0,>=0.8.1->opsml-data==0.1.1rc1673236397->-r requirements.txt (line 3)) (2.1.1)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/steven.forrester/Library/Caches/pypoetry/virtualenvs/jupyter-local-dev-n7or5Q-O-py3.9/lib/python3.9/site-packages (from aiohttp->cloud-sql-python-connector[pymysql]<0.9.0,>=0.8.1->opsml-data==0.1.1rc1673236397->-r requirements.txt (line 3)) (1.3.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/steven.forrester/Library/Caches/pypoetry/virtualenvs/jupyter-local-dev-n7or5Q-O-py3.9/lib/python3.9/site-packages (from aiohttp->cloud-sql-python-connector[pymysql]<0.9.0,>=0.8.1->opsml-data==0.1.1rc1673236397->-r requirements.txt (line 3)) (1.8.2)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /Users/steven.forrester/Library/Caches/pypoetry/virtualenvs/jupyter-local-dev-n7or5Q-O-py3.9/lib/python3.9/site-packages (from aiohttp->cloud-sql-python-connector[pymysql]<0.9.0,>=0.8.1->opsml-data==0.1.1rc1673236397->-r requirements.txt (line 3)) (4.0.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/steven.forrester/Library/Caches/pypoetry/virtualenvs/jupyter-local-dev-n7or5Q-O-py3.9/lib/python3.9/site-packages (from aiohttp->cloud-sql-python-connector[pymysql]<0.9.0,>=0.8.1->opsml-data==0.1.1rc1673236397->-r requirements.txt (line 3)) (1.3.1)
# Requirement already satisfied: packaging in /Users/steven.forrester/Library/Caches/pypoetry/virtualenvs/jupyter-local-dev-n7or5Q-O-py3.9/lib/python3.9/site-packages (from fastparquet<0.9.0,>=0.8.0->pyshipt==2.1.8->opsml-data==0.1.1rc1673236397->-r requirements.txt (line 3)) (21.3)
# Requirement already satisfied: cramjam>=2.3.0 in /Users/steven.forrester/Library/Caches/pypoetry/virtualenvs/jupyter-local-dev-n7or5Q-O-py3.9/lib/python3.9/site-packages (from fastparquet<0.9.0,>=0.8.0->pyshipt==2.1.8->opsml-data==0.1.1rc1673236397->-r requirements.txt (line 3)) (2.6.2)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.56.2 in /Users/steven.forrester/Library/Caches/pypoetry/virtualenvs/jupyter-local-dev-n7or5Q-O-py3.9/lib/python3.9/site-packages (from google-api-core<3.0dev,>=1.29.0->google-cloud-storage==1.44.0->opsml-data==0.1.1rc1673236397->-r requirements.txt (line 3)) (1.57.0)
# Requirement already satisfied: grpcio-status<2.0dev,>=1.33.2 in /Users/steven.forrester/Library/Caches/pypoetry/virtualenvs/jupyter-local-dev-n7or5Q-O-py3.9/lib/python3.9/site-packages (from google-api-core<3.0dev,>=1.29.0->google-cloud-storage==1.44.0->opsml-data==0.1.1rc1673236397->-r requirements.txt (line 3)) (1.48.2)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in /Users/steven.forrester/Library/Caches/pypoetry/virtualenvs/jupyter-local-dev-n7or5Q-O-py3.9/lib/python3.9/site-packages (from google-api-core<3.0dev,>=1.29.0->google-cloud-storage==1.44.0->opsml-data==0.1.1rc1673236397->-r requirements.txt (line 3)) (1.51.1)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /Users/steven.forrester/Library/Caches/pypoetry/virtualenvs/jupyter-local-dev-n7or5Q-O-py3.9/lib/python3.9/site-packages (from google-resumable-media<3.0dev,>=1.3.0->google-cloud-storage==1.44.0->opsml-data==0.1.1rc1673236397->-r requirements.txt (line 3)) (1.5.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/steven.forrester/Library/Caches/pypoetry/virtualenvs/jupyter-local-dev-n7or5Q-O-py3.9/lib/python3.9/site-packages (from jinja2<4.0.0,>=3.0.3->pyshipt==2.1.8->opsml-data==0.1.1rc1673236397->-r requirements.txt (line 3)) (2.0.1)
# Requirement already satisfied: pyrsistent>=0.14.0 in /Users/steven.forrester/Library/Caches/pypoetry/virtualenvs/jupyter-local-dev-n7or5Q-O-py3.9/lib/python3.9/site-packages (from jsonschema>=3.0->altair<5.0.0,>=4.2.0->opsml-data==0.1.1rc1673236397->-r requirements.txt (line 3)) (0.19.2)
# Requirement already satisfied: tomli>=1.1.0 in /Users/steven.forrester/Library/Caches/pypoetry/virtualenvs/jupyter-local-dev-n7or5Q-O-py3.9/lib/python3.9/site-packages (from mypy>=0.910->sqlalchemy[mypy]<2.0.0,>=1.4.46->opsml-data==0.1.1rc1673236397->-r requirements.txt (line 3)) (2.0.1)
# Requirement already satisfied: mypy-extensions>=0.4.3 in /Users/steven.forrester/Library/Caches/pypoetry/virtualenvs/jupyter-local-dev-n7or5Q-O-py3.9/lib/python3.9/site-packages (from mypy>=0.910->sqlalchemy[mypy]<2.0.0,>=1.4.46->opsml-data==0.1.1rc1673236397->-r requirements.txt (line 3)) (0.4.3)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /Users/steven.forrester/Library/Caches/pypoetry/virtualenvs/jupyter-local-dev-n7or5Q-O-py3.9/lib/python3.9/site-packages (from pyasn1-modules>=0.2.1->google-auth==1.35.0->opsml-data==0.1.1rc1673236397->-r requirements.txt (line 3)) (0.4.8)
# Requirement already satisfied: tenacity<9.0.0,>=8.0.1 in /Users/steven.forrester/Library/Caches/pypoetry/virtualenvs/jupyter-local-dev-n7or5Q-O-py3.9/lib/python3.9/site-packages (from pyshipt-experiments<3.0.0,>=2.1.0->pyshipt==2.1.8->opsml-data==0.1.1rc1673236397->-r requirements.txt (line 3)) (8.1.0)
# Requirement already satisfied: semver<3.0.0,>=2.13.0 in /Users/steven.forrester/Library/Caches/pypoetry/virtualenvs/jupyter-local-dev-n7or5Q-O-py3.9/lib/python3.9/site-packages (from pyshipt-experiments<3.0.0,>=2.1.0->pyshipt==2.1.8->opsml-data==0.1.1rc1673236397->-r requirements.txt (line 3)) (2.13.0)
# Requirement already satisfied: comet-ml<4.0.0,>=3.14.0 in /Users/steven.forrester/Library/Caches/pypoetry/virtualenvs/jupyter-local-dev-n7or5Q-O-py3.9/lib/python3.9/site-packages (from pyshipt-experiments<3.0.0,>=2.1.0->pyshipt==2.1.8->opsml-data==0.1.1rc1673236397->-r requirements.txt (line 3)) (3.31.21)
# Requirement already satisfied: pyyaml<6.0,>=5.0 in /Users/steven.forrester/Library/Caches/pypoetry/virtualenvs/jupyter-local-dev-n7or5Q-O-py3.9/lib/python3.9/site-packages (from pyshipt-experiments<3.0.0,>=2.1.0->pyshipt==2.1.8->opsml-data==0.1.1rc1673236397->-r requirements.txt (line 3)) (5.4.1)
# Requirement already satisfied: confluent-kafka<2.0.0,>=1.0.0 in /Users/steven.forrester/Library/Caches/pypoetry/virtualenvs/jupyter-local-dev-n7or5Q-O-py3.9/lib/python3.9/site-packages (from pyshipt-streams<4.0.0,>=3.0.0->pyshipt==2.1.8->opsml-data==0.1.1rc1673236397->-r requirements.txt (line 3)) (1.9.2)
# Requirement already satisfied: orjson<4.0.0,>=3.6.7 in /Users/steven.forrester/Library/Caches/pypoetry/virtualenvs/jupyter-local-dev-n7or5Q-O-py3.9/lib/python3.9/site-packages (from pyshipt-streams<4.0.0,>=3.0.0->pyshipt==2.1.8->opsml-data==0.1.1rc1673236397->-r requirements.txt (line 3)) (3.8.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/steven.forrester/Library/Caches/pypoetry/virtualenvs/jupyter-local-dev-n7or5Q-O-py3.9/lib/python3.9/site-packages (from requests<3.0.0dev,>=2.18.0->google-cloud-storage==1.44.0->opsml-data==0.1.1rc1673236397->-r requirements.txt (line 3)) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/steven.forrester/Library/Caches/pypoetry/virtualenvs/jupyter-local-dev-n7or5Q-O-py3.9/lib/python3.9/site-packages (from requests<3.0.0dev,>=2.18.0->google-cloud-storage==1.44.0->opsml-data==0.1.1rc1673236397->-r requirements.txt (line 3)) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/steven.forrester/Library/Caches/pypoetry/virtualenvs/jupyter-local-dev-n7or5Q-O-py3.9/lib/python3.9/site-packages (from requests<3.0.0dev,>=2.18.0->google-cloud-storage==1.44.0->opsml-data==0.1.1rc1673236397->-r requirements.txt (line 3)) (1.26.13)
# Requirement already satisfied: pyOpenSSL<23.0.0,>=16.2.0 in /Users/steven.forrester/Library/Caches/pypoetry/virtualenvs/jupyter-local-dev-n7or5Q-O-py3.9/lib/python3.9/site-packages (from snowflake-connector-python<3.0.0,>=2.7.6->pyshipt==2.1.8->opsml-data==0.1.1rc1673236397->-r requirements.txt (line 3)) (22.1.0)
# Requirement already satisfied: cffi<2.0.0,>=1.9 in /Users/steven.forrester/Library/Caches/pypoetry/virtualenvs/jupyter-local-dev-n7or5Q-O-py3.9/lib/python3.9/site-packages (from snowflake-connector-python<3.0.0,>=2.7.6->pyshipt==2.1.8->opsml-data==0.1.1rc1673236397->-r requirements.txt (line 3)) (1.15.1)
# Requirement already satisfied: oscrypto<2.0.0 in /Users/steven.forrester/Library/Caches/pypoetry/virtualenvs/jupyter-local-dev-n7or5Q-O-py3.9/lib/python3.9/site-packages (from snowflake-connector-python<3.0.0,>=2.7.6->pyshipt==2.1.8->opsml-data==0.1.1rc1673236397->-r requirements.txt (line 3)) (1.3.0)
# Requirement already satisfied: filelock<4,>=3.5 in /Users/steven.forrester/Library/Caches/pypoetry/virtualenvs/jupyter-local-dev-n7or5Q-O-py3.9/lib/python3.9/site-packages (from snowflake-connector-python<3.0.0,>=2.7.6->pyshipt==2.1.8->opsml-data==0.1.1rc1673236397->-r requirements.txt (line 3)) (3.8.2)
# Requirement already satisfied: asn1crypto<2.0.0,>0.24.0 in /Users/steven.forrester/Library/Caches/pypoetry/virtualenvs/jupyter-local-dev-n7or5Q-O-py3.9/lib/python3.9/site-packages (from snowflake-connector-python<3.0.0,>=2.7.6->pyshipt==2.1.8->opsml-data==0.1.1rc1673236397->-r requirements.txt (line 3)) (1.5.1)
# Requirement already satisfied: pyjwt<3.0.0 in /Users/steven.forrester/Library/Caches/pypoetry/virtualenvs/jupyter-local-dev-n7or5Q-O-py3.9/lib/python3.9/site-packages (from snowflake-connector-python<3.0.0,>=2.7.6->pyshipt==2.1.8->opsml-data==0.1.1rc1673236397->-r requirements.txt (line 3)) (2.6.0)
# Requirement already satisfied: pycryptodomex!=3.5.0,<4.0.0,>=3.2 in /Users/steven.forrester/Library/Caches/pypoetry/virtualenvs/jupyter-local-dev-n7or5Q-O-py3.9/lib/python3.9/site-packages (from snowflake-connector-python<3.0.0,>=2.7.6->pyshipt==2.1.8->opsml-data==0.1.1rc1673236397->-r requirements.txt (line 3)) (3.16.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /Users/steven.forrester/Library/Caches/pypoetry/virtualenvs/jupyter-local-dev-n7or5Q-O-py3.9/lib/python3.9/site-packages (from google-auth-oauthlib->gcsfs<2023.0.0,>=2022.11.0->opsml-data==0.1.1rc1673236397->-r requirements.txt (line 3)) (1.3.1)
# Requirement already satisfied: pycparser in /Users/steven.forrester/Library/Caches/pypoetry/virtualenvs/jupyter-local-dev-n7or5Q-O-py3.9/lib/python3.9/site-packages (from cffi<2.0.0,>=1.9->snowflake-connector-python<3.0.0,>=2.7.6->pyshipt==2.1.8->opsml-data==0.1.1rc1673236397->-r requirements.txt (line 3)) (2.21)
# Requirement already satisfied: requests-toolbelt>=0.8.0 in /Users/steven.forrester/Library/Caches/pypoetry/virtualenvs/jupyter-local-dev-n7or5Q-O-py3.9/lib/python3.9/site-packages (from comet-ml<4.0.0,>=3.14.0->pyshipt-experiments<3.0.0,>=2.1.0->pyshipt==2.1.8->opsml-data==0.1.1rc1673236397->-r requirements.txt (line 3)) (0.10.1)
# Requirement already satisfied: websocket-client<1.4.0,>=0.55.0 in /Users/steven.forrester/Library/Caches/pypoetry/virtualenvs/jupyter-local-dev-n7or5Q-O-py3.9/lib/python3.9/site-packages (from comet-ml<4.0.0,>=3.14.0->pyshipt-experiments<3.0.0,>=2.1.0->pyshipt==2.1.8->opsml-data==0.1.1rc1673236397->-r requirements.txt (line 3)) (1.3.3)
# Requirement already satisfied: simplejson in /Users/steven.forrester/Library/Caches/pypoetry/virtualenvs/jupyter-local-dev-n7or5Q-O-py3.9/lib/python3.9/site-packages (from comet-ml<4.0.0,>=3.14.0->pyshipt-experiments<3.0.0,>=2.1.0->pyshipt==2.1.8->opsml-data==0.1.1rc1673236397->-r requirements.txt (line 3)) (3.18.1)
# Requirement already satisfied: everett[ini]>=1.0.1 in /Users/steven.forrester/Library/Caches/pypoetry/virtualenvs/jupyter-local-dev-n7or5Q-O-py3.9/lib/python3.9/site-packages (from comet-ml<4.0.0,>=3.14.0->pyshipt-experiments<3.0.0,>=2.1.0->pyshipt==2.1.8->opsml-data==0.1.1rc1673236397->-r requirements.txt (line 3)) (3.1.0)
# Requirement already satisfied: wrapt>=1.11.2 in /Users/steven.forrester/Library/Caches/pypoetry/virtualenvs/jupyter-local-dev-n7or5Q-O-py3.9/lib/python3.9/site-packages (from comet-ml<4.0.0,>=3.14.0->pyshipt-experiments<3.0.0,>=2.1.0->pyshipt==2.1.8->opsml-data==0.1.1rc1673236397->-r requirements.txt (line 3)) (1.14.1)
# Requirement already satisfied: sentry-sdk>=1.1.0 in /Users/steven.forrester/Library/Caches/pypoetry/virtualenvs/jupyter-local-dev-n7or5Q-O-py3.9/lib/python3.9/site-packages (from comet-ml<4.0.0,>=3.14.0->pyshipt-experiments<3.0.0,>=2.1.0->pyshipt==2.1.8->opsml-data==0.1.1rc1673236397->-r requirements.txt (line 3)) (1.12.1)
# Requirement already satisfied: dulwich!=0.20.33,>=0.20.6 in /Users/steven.forrester/Library/Caches/pypoetry/virtualenvs/jupyter-local-dev-n7or5Q-O-py3.9/lib/python3.9/site-packages (from comet-ml<4.0.0,>=3.14.0->pyshipt-experiments<3.0.0,>=2.1.0->pyshipt==2.1.8->opsml-data==0.1.1rc1673236397->-r requirements.txt (line 3)) (0.20.50)
# Requirement already satisfied: semantic-version>=2.8.0 in /Users/steven.forrester/Library/Caches/pypoetry/virtualenvs/jupyter-local-dev-n7or5Q-O-py3.9/lib/python3.9/site-packages (from comet-ml<4.0.0,>=3.14.0->pyshipt-experiments<3.0.0,>=2.1.0->pyshipt==2.1.8->opsml-data==0.1.1rc1673236397->-r requirements.txt (line 3)) (2.10.0)
# Requirement already satisfied: wurlitzer>=1.0.2 in /Users/steven.forrester/Library/Caches/pypoetry/virtualenvs/jupyter-local-dev-n7or5Q-O-py3.9/lib/python3.9/site-packages (from comet-ml<4.0.0,>=3.14.0->pyshipt-experiments<3.0.0,>=2.1.0->pyshipt==2.1.8->opsml-data==0.1.1rc1673236397->-r requirements.txt (line 3)) (3.0.3)
# Requirement already satisfied: oauthlib>=3.0.0 in /Users/steven.forrester/Library/Caches/pypoetry/virtualenvs/jupyter-local-dev-n7or5Q-O-py3.9/lib/python3.9/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib->gcsfs<2023.0.0,>=2022.11.0->opsml-data==0.1.1rc1673236397->-r requirements.txt (line 3)) (3.2.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /Users/steven.forrester/Library/Caches/pypoetry/virtualenvs/jupyter-local-dev-n7or5Q-O-py3.9/lib/python3.9/site-packages (from packaging->fastparquet<0.9.0,>=0.8.0->pyshipt==2.1.8->opsml-data==0.1.1rc1673236397->-r requirements.txt (line 3)) (3.0.9)
# Requirement already satisfied: configobj in /Users/steven.forrester/Library/Caches/pypoetry/virtualenvs/jupyter-local-dev-n7or5Q-O-py3.9/lib/python3.9/site-packages (from everett[ini]>=1.0.1->comet-ml<4.0.0,>=3.14.0->pyshipt-experiments<3.0.0,>=2.1.0->pyshipt==2.1.8->opsml-data==0.1.1rc1673236397->-r requirements.txt (line 3)) (5.0.6)
# Installing collected packages: opsml-data
#   Attempting uninstall: opsml-data
#     Found existing installation: opsml-data 0.1.1rc1673234251
#     Uninstalling opsml-data-0.1.1rc1673234251:
#       Successfully uninstalled opsml-data-0.1.1rc1673234251
# Successfully installed opsml-data-0.1.1rc1673236397

# %%
from opsml_data import DataCard, DataRegistry
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split

# %% [markdown]
# ### Instantiate data registry

# %%
registry = DataRegistry()

# %% [markdown]
# #### Example 1: Creating data (with index splits) and registering it to the data registry
# Create fake data

# %%
mu_1, mu_2 = -4, 4
X_data = np.random.normal(mu_1, 2.0, size=(1000, 10))
y_data = np.random.randint(2, 100, size=(1000, 1))

col_names = []
for i in range(0, X_data.shape[1]):
    col_names.append(f"col_{i}")

# Create dataframe
data = pd.DataFrame(X_data, columns=col_names)
data["target"] = y_data
data.head()
# Out:
#       col_0     col_1     col_2     col_3     col_4     col_5     col_6  \
# 0 -5.160202 -0.025896 -3.485771 -2.555679 -3.203268 -4.299549 -8.064235
# 1 -6.664674 -1.111773 -5.620179 -3.227847 -6.907431 -6.443197 -5.244840
# 2 -6.371372 -1.900902 -3.548210 -4.417654 -7.896266 -7.032659 -4.702275
# 3 -6.679026 -5.668980 -3.287953 -6.197477 -2.400010 -5.504350 -4.598107
# 4 -2.817011 -2.319162 -2.761658 -2.004763 -3.584133 -2.995775 -3.674715
#
#       col_7     col_8     col_9  target
# 0 -5.154186 -2.356566 -3.020622      35
# 1 -3.423994 -4.568824 -1.610850      84
# 2 -5.272811 -4.481945 -3.053206      13
# 3 -5.332875 -2.997450 -4.690829      21
# 4 -3.954267 -4.323538 -5.306450      81

# %% [markdown]
# ##### Create train test splits

# %%
train_idx, test_idx = train_test_split(np.arange(data.shape[0]), test_size=0.3)

# %% [markdown]
# ##### Create DataCard
# - check out the docstring for input specifications
# - Required arguments:
#     - data: pandas dataframe, numpy array, or pyarrow table
#     - data_name: Name for the data
#     - team: team name
#     - user_email: User email

# %%
DATA_NAME = "synthetic_data"
TEAM = "SPMS"
USER_EMAIL = "steven.forrester@shipt.com"
DATA_SPLITS = [
    {"label":"train", "indices": train_idx},
    {"label":"test", "indices": test_idx}
]

data_card = DataCard(
    data_name=DATA_NAME, 
    team=TEAM, 
    user_email=USER_EMAIL, 
    data=data, 
    data_splits=DATA_SPLITS
)

# confirm data
data_card.data
# Out:
#         col_0     col_1     col_2     col_3     col_4     col_5     col_6  \
# 0   -5.160202 -0.025896 -3.485771 -2.555679 -3.203268 -4.299549 -8.064235
# 1   -6.664674 -1.111773 -5.620179 -3.227847 -6.907431 -6.443197 -5.244840
# 2   -6.371372 -1.900902 -3.548210 -4.417654 -7.896266 -7.032659 -4.702275
# 3   -6.679026 -5.668980 -3.287953 -6.197477 -2.400010 -5.504350 -4.598107
# 4   -2.817011 -2.319162 -2.761658 -2.004763 -3.584133 -2.995775 -3.674715
# ..        ...       ...       ...       ...       ...       ...       ...
# 995 -4.380297 -3.171645 -0.627990 -1.688472  0.729206 -2.883401 -5.145330
# 996 -6.938969 -1.486126 -2.949069  0.283093 -1.474004 -6.649144 -7.759252
# 997 -5.163608 -6.041067 -3.581658 -6.051015 -5.134530 -1.833917 -2.401548
# 998 -2.501005 -5.510995 -4.818315 -2.451338 -2.146552 -4.271094  0.001651
# 999 -4.923790 -4.778539 -4.394906 -2.675709 -6.746700 -5.537674 -5.070666
#
#         col_7     col_8     col_9  target
# 0   -5.154186 -2.356566 -3.020622      35
# 1   -3.423994 -4.568824 -1.610850      84
# 2   -5.272811 -4.481945 -3.053206      13
# 3   -5.332875 -2.997450 -4.690829      21
# 4   -3.954267 -4.323538 -5.306450      81
# ..        ...       ...       ...     ...
# 995 -2.494345 -2.115308 -1.231598      68
# 996 -3.756787 -5.144261 -3.701229       4
# 997 -6.646110 -3.172974 -4.748680      99
# 998 -4.784271 -5.047539 -5.457438      30
# 999 -0.912951 -2.646555 -4.272509      48
#
# [1000 rows x 11 columns]

# %% [markdown]
# ##### Confirm data splits
# - data_card will return splits in the form of a pydantic model

# %%
splits = data_card.split_data()
splits.train.shape, splits.test.shape
# Out:
# ((700, 11), (300, 11))

# %% [markdown]
# #### Save data to registry

# %%
registry.register_data(data_card=data_card)
# Out:
# {"level": "INFO", "message": "Table: synthetic_data registered as version 3", "timestamp": "2023-01-09T02:57:29.874955Z", "app_env": "staging", "host": null, "version": null}

# %% [markdown]
# ### Listing DataCards in the registry

# %%
# list data
registry_data = registry.list_data(data_name=DATA_NAME, team=TEAM, version=data_card.version)
assert data_card.uid == registry_data["uid"].values[0]

registry_data.head()
# Out:
#                                 uid        date      timestamp  app_env  \
# 0  d641649db0e64b0a9fcfa9c8178b90ef  2023-01-08  1673232819415  staging
#
#         data_name  team                                           data_uri  \
# 0  synthetic_data  SPMS  gs://ds-opsml-stg/data_registry/SPMS/synthetic...
#
#   drift_uri                                        feature_map  \
# 0      None  {'col_0': 'double', 'col_1': 'double', 'col_2'...
#
#                                          data_splits  data_type  version  \
# 0  {'splits': [{'label': 'train', 'indices': [61,...  DataFrame        3
#
#                    user_email dependent_vars
# 0  steven.forrester@shipt.com           None

# %% [markdown]
# ### Loading DataCards from the the registry

# %%
# load data_card
new_data_card = registry.load_data(data_name=DATA_NAME, team=TEAM)
assert new_data_card.uid == data_card.uid
